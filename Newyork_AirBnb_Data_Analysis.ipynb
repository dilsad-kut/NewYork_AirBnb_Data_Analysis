# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(8,6)})

# %%
df = pd.read_csv("Dataset/AB_NYC_2019.csv")

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.drop(['id','host_id','host_name'], axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# name                                 16
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.fillna({"name":0, "last_review":0, "reviews_per_month":0}, inplace=True)

# %%
df.isnull().sum()
# Out:
# name                              0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            48895 non-null  object
#  1   neighbourhood_group             48895 non-null  object
#  2   neighbourhood                   48895 non-null  object
#  3   latitude                        48895 non-null  float64
#  4   longitude                       48895 non-null  float64
#  5   room_type                       48895 non-null  object
#  6   price                           48895 non-null  int64
#  7   minimum_nights                  48895 non-null  int64
#  8   number_of_reviews               48895 non-null  int64
#  9   last_review                     48895 non-null  object
#  10  reviews_per_month               48895 non-null  float64
#  11  calculated_host_listings_count  48895 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                                   count        mean         std       min  \
# latitude                        48895.0   40.728949    0.054530  40.49979
# longitude                       48895.0  -73.952170    0.046157 -74.24442
# price                           48895.0  152.720687  240.154170   0.00000
# minimum_nights                  48895.0    7.029962   20.510550   1.00000
# number_of_reviews               48895.0   23.274466   44.550582   0.00000
# reviews_per_month               48895.0    1.090910    1.597283   0.00000
# calculated_host_listings_count  48895.0    7.143982   32.952519   1.00000
# availability_365                48895.0  112.781327  131.622289   0.00000
#
#                                      25%        50%         75%          max
# latitude                        40.69010   40.72307   40.763115     40.91306
# longitude                      -73.98307  -73.95568  -73.936275    -73.71299
# ...

# %%
df["room_type"].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
df["neighbourhood_group"].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df["room_type"].value_counts().plot.barh().set_title("Konaklayacak Misafirlerin Kalınan Oda Tipine Göre Dağılım Grafiği")
# Out:
# Text(0.5, 1.0, 'Konaklayacak Misafirlerin Kalınan Oda Tipine Göre Dağılım Grafiği')

# %%
df["neighbourhood_group"].value_counts().plot.barh().set_title("Konaklayacak Misafirlerin Bölge Bazında Dağılım Grafiği")
# Out:
# Text(0.5, 1.0, 'Koanklayacak Misafirlerin Bölge Bazında Dağılım Grafiği')

# %%
df["room_type"].index
# Out:
# RangeIndex(start=0, stop=48895, step=1)

# %%
sns.barplot(x="room_type", y=df["room_type"].index, data=df, color="yellow").set_title("Oda Tipi Dağılımları")
# Out:
# Text(0.5, 1.0, 'Oda Tipi Dağılımları')

# %%
sns.barplot(x="room_type", y="price", hue="neighbourhood_group", data=df)
plt.title("Oda Tiplerine Göre Fiyatların Bölge Bazında İncelenmesi")
# Out:
# Text(0.5, 1.0, 'Oda Tiplerine Göre Fiyatların Bölge Bazında İncelenmesi')

# %%
df2 = df.copy()
df2
# Out:
#                                                     name neighbourhood_group  \
# 0                     Clean & quiet apt home by the park            Brooklyn
# 1                                  Skylit Midtown Castle           Manhattan
# 2                    THE VILLAGE OF HARLEM....NEW YORK !           Manhattan
# 3                        Cozy Entire Floor of Brownstone            Brooklyn
# 4       Entire Apt: Spacious Studio/Loft by central park           Manhattan
# ...                                                  ...                 ...
# 48890    Charming one bedroom - newly renovated rowhouse            Brooklyn
# 48891      Affordable room in Bushwick/East Williamsburg            Brooklyn
# 48892            Sunny Studio at Historical Neighborhood           Manhattan
# 48893               43rd St. Time Square-cozy single bed           Manhattan
# 48894  Trendy duplex in the very heart of Hell's Kitchen           Manhattan
#
# ...

# %%
df2.head()
# Out:
#                                                name neighbourhood_group  \
# 0                Clean & quiet apt home by the park            Brooklyn
# 1                             Skylit Midtown Castle           Manhattan
# 2               THE VILLAGE OF HARLEM....NEW YORK !           Manhattan
# 3                   Cozy Entire Floor of Brownstone            Brooklyn
# 4  Entire Apt: Spacious Studio/Loft by central park           Manhattan
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0    Kensington  40.64749  -73.97237     Private room    149               1
# 1       Midtown  40.75362  -73.98377  Entire home/apt    225               1
# 2        Harlem  40.80902  -73.94190     Private room    150               3
# 3  Clinton Hill  40.68514  -73.95976  Entire home/apt     89               1
# 4   East Harlem  40.79851  -73.94399  Entire home/apt     80              10
#
#    number_of_reviews last_review  reviews_per_month  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            48895 non-null  object
#  1   neighbourhood_group             48895 non-null  object
#  2   neighbourhood                   48895 non-null  object
#  3   latitude                        48895 non-null  float64
#  4   longitude                       48895 non-null  float64
#  5   room_type                       48895 non-null  object
#  6   price                           48895 non-null  int64
#  7   minimum_nights                  48895 non-null  int64
#  8   number_of_reviews               48895 non-null  int64
#  9   last_review                     48895 non-null  object
#  10  reviews_per_month               48895 non-null  float64
#  11  calculated_host_listings_count  48895 non-null  int64
# ...

# %%
from pandas.api.types import CategoricalDtype
roomtype_kategoriler = ["Private room","Entire home/apt","Shared room"]
df2.room_type = df2.room_type.astype(CategoricalDtype(categories = roomtype_kategoriler , ordered = True))

# %%
sns.FacetGrid(df2, hue = "room_type", height = 5, xlim = (0,1000)).map(sns.kdeplot, "price", shade = True).add_legend()

# %%
sns.pairplot(df, hue = "neighbourhood_group")

# %%
sns.heatmap(df.corr(), cmap="Blues", annot = True, linewidths = 2)
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
sns.scatterplot( x= df['price'], y=df['availability_365'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='availability_365'>

# %%
sns.catplot(data=df, x="neighbourhood_group", y="price", kind= 'strip' ,hue="room_type")
plt.title("Ortalama Fiyata Göre Bölgeler ve Oda Tipleri")
# Out:
# Text(0.5, 1.0, 'Ortalama Fiyata Göre Bölgeler ve Oda Tipleri')

# %%
sns.scatterplot( x= df['number_of_reviews'], y=df['reviews_per_month'])
# Out:
# <AxesSubplot:xlabel='number_of_reviews', ylabel='reviews_per_month'>

# %%
df.groupby("room_type").sum().plot.pie(y="reviews_per_month", autopct="%.1f%%", ylabel="", legend=False, figsize=(10,6))
plt.title("Oda Tipine Göre Aylık İncelemeler")
# Out:
# Text(0.5, 1.0, 'Oda Tipine Göre Aylık İncelemeler')

# %%
sns.histplot(df["price"], kde=True, bins=80)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.kdeplot(df["price"], shade=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>
